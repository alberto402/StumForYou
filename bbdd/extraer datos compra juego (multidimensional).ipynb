# %%
import random
import mysql.connector
import json
import string
import datetime as dt
from pymongo import MongoClient

def getGenero(argument):
    switcher = {        
        5: "action",
        6: "adventure",
        7: "casual",
        8: "strategy",
        9: "RPG",
        10: "simulation",
        11: "early_access",
        12: "free_to_play",
        13: "sports",
        14: "racing",
        15: "massively_multiplayer"
    }
    return switcher.get(argument, argument)

myclient = MongoClient("mongodb://localhost:27017/")
mydb = myclient['stum']
mycol = mydb["usuarios"]

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    database='stum',
    passwd=""
)
from datetime import datetime,timedelta
hoy = datetime.now()
dias = timedelta(days=7)
semana_pasada = hoy-dias  
#se comprueba que sea domingo (0)
comp=hoy.strftime("%w")
print(comp)
if (comp == '5') :#--------------------------------------------------------------cuidado
    
    hoy=hoy.strftime("%Y-%m-%d")
    #semana_pasada=semana_pasada.strftime("%Y:%m:%d")
    
    semana_pasada ="2017-01-01"#-------------------------------------------------para pruebas
    print(hoy,semana_pasada)
    mycursor = mydb.cursor()

    mycursor.execute("SELECT * FROM transacciones_compra WHERE fecha_compra BETWEEN %s AND  %s", (semana_pasada,hoy,))
    transacciones = mycursor.fetchall()
    print(transacciones)
    tipo_movimiento = "compra"
    for t in transacciones :
   
    #"movimiento"
        precio_final = t[1]
        mycursor.execute("SELECT * FROM compra_juegos WHERE id_transaccion = %s", (t[0],))
        compra = mycursor.fetchall()
        cantidad = len(compra)
    #fecha
        anyo=t[2].strftime("%Y")
        mes=t[2].strftime("%m")
        dia=t[2].strftime("%d")
    #juego
        if(len(compra)>0) :
            mycursor.execute("SELECT id_juego FROM claves_juegos WHERE id_clave = %s", (compra[0][2],))
            puntero_juego = mycursor.fetchone()[0]
            mycursor.execute("SELECT * FROM juegos WHERE id_juego = %s", (puntero_juego,))
            juego = mycursor.fetchone()
            genero= []
            #sacar genero
            for a in range (5,15) :
                if (juego[a]==True) :
                    genero.append(getGenero(a))
            precio_juego=juego[3]
            clasificacion=juego[1]
     #dlc
        if(len(compra)<=0) :
            mycursor.execute("SELECT * FROM compra_dlcs WHERE id_transaccion = %s", (t[0],))
            compra = mycursor.fetchall()
            cantidad = len(compra)
            mycursor.execute("SELECT id_juego FROM claves_dlc WHERE id_clave = %s", (compra[0][2],))
            puntero_dlc = mycursor.fetchone()[0]
            mycursor.execute("SELECT * FROM dlcs WHERE id_dlc = %s", (puntero_dlc,))
            dlc = mycursor.fetchone()
            tipo= dlc[3]
            precio_dlc=dlc[1]
            
    #proveedor
        puntero_proveedor=compra[0][0]
        mycursor.execute("SELECT * FROM proveedor WHERE id_proveedor = %s", (puntero_proveedor,))
        provedor = mycursor.fetchone()
        pais= provedor[3]
        valoracion=provedor[1]
        print("---------------------------------------------------------------")
        print("precio_final:",precio_final,"tipo_movimiento:",tipo_movimiento,"cantidad:",cantidad,"anyo:",anyo,"mes:",mes,
              "dia",dia,"puntero_juego",puntero_juego,"genero",genero,"precio",precio,
              "clasificacion",clasificacion,"puntero_proveedor",puntero_proveedor,"pais",pais,"valoracion",valoracion)
# Out:
# 5
# 2020-01-10 2017-01-01
# [(1, 0, datetime.date(2019, 3, 21)), (2, 38, datetime.date(2019, 11, 26)), (3, 60, datetime.date(2018, 4, 8)), (4, 88, datetime.date(2019, 7, 22))]
# ---------------------------------------------------------------
# precio_final: 0 tipo_movimiento: compra cantidad: 67 anyo: 2019 mes: 03 dia 21 puntero_juego 4958 genero ['action'] precio 1 clasificacion INDIE puntero_proveedor 31 pais Bulgaria valoracion 8
# ---------------------------------------------------------------
# precio_final: 38 tipo_movimiento: compra cantidad: 19 anyo: 2019 mes: 11 dia 26 puntero_juego 10482 genero ['action', 'casual', 'RPG'] precio 4 clasificacion INDIE puntero_proveedor 33 pais Macedonia valoracion 5
# ---------------------------------------------------------------
# precio_final: 60 tipo_movimiento: compra cantidad: 20 anyo: 2018 mes: 04 dia 08 puntero_juego 5440 genero ['casual'] precio 5 clasificacion INDIE puntero_proveedor 15 pais Nepal valoracion 10
# ---------------------------------------------------------------
# precio_final: 88 tipo_movimiento: compra cantidad: 22 anyo: 2019 mes: 07 dia 22 puntero_juego 1705 genero [] precio 5 clasificacion AAA puntero_proveedor 31 pais Bulgaria valoracion 8
