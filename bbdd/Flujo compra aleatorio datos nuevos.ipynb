# %%
import mysql.connector
import pandas as pd 
from mysql.connector import errorcode
import random
from datetime import datetime
try:
    cnx = mysql.connector.connect(
      host="localhost",
      user="root",
      database='sgdi',
      passwd=""
    )
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print("Database does not exist")
    else:
        print(err)



cursor = cnx.cursor()
#elejimos un juego
cursor.execute("SELECT COUNT(*) FROM juegos")
numjuegos = cursor.fetchone()[0] + 1
id_juego = random.randrange(1,numjuegos)
sql = """SELECT * FROM juegos WHERE id_juego = %s """ % (id_juego)
cursor.execute(sql)
juego = cursor.fetchone()
#elejimos un proveedor
cursor.execute("SELECT COUNT(*) FROM proveedor")
numprov = cursor.fetchone()[0] + 1
id_proveedor = random.randrange(1,numprov)
sql = """SELECT * FROM proveedor WHERE id_proveedor = %s """ % (id_proveedor)
cursor.execute(sql)
proveedor = cursor.fetchone()
# añadimos a la tabla transacción compra
elem = random.randrange(0,100)
sql = "INSERT INTO transacciones_compra (precio_total, fecha_compra) VALUES (%s, %s)"
descuento =  random.randrange(1,10) /10
print(descuento)
preciojuego=int(juego[3]*descuento )

#fecha= aleatoriofecha
inicio = datetime(2017, 1, 30)
final =  datetime(2020, 1, 1)
fecha = inicio + (final - inicio) * random.random()

val = (preciojuego * elem, fecha)
cursor.execute(sql,val)
cnx.commit()
cursor.execute("SELECT MAX(id_transaccion) FROM transacciones_compra")
id_transac = cursor.fetchone()[0]
# añadimos clave
print(elem)
for i in range (0, elem) :
    aux = True
    while aux :
        num1 = str(random.randrange(1,999999))
        num2 = str(random.randrange(1,9999))
        clave = num1.zfill(6) + '-' + num2.zfill(4)
        sql = """SELECT * FROM claves_juegos WHERE clave = %s """ % (clave)
        cursor.execute(sql)
        if(len(cursor.fetchall()) == 0) :
            aux = False
    sql = "INSERT INTO claves_juegos (clave, fecha_anexion, id_juego) VALUES (%s, %s, %s)"
    val = (clave, fecha, id_juego)
    cursor.execute(sql,val)
    cnx.commit()
    cursor.execute("SELECT MAX(id_clave) FROM claves_juegos")
    id_clave = cursor.fetchone()[0]
                
            
        
        
    # añadimos compra
    sql = "INSERT INTO compra_juegos (id_proveedor, id_transaccion, id_claves_juego, id_claves_dlc, precio) VALUES (%s, %s, %s, %s, %s)"
    val = (id_proveedor, id_transac, id_clave, None, preciojuego)
    cursor.execute(sql,val)
    cnx.commit()
    print("proveedor :" , id_proveedor , "id_transac :" , id_transac ,"id_clave :" , id_clave ,  "id_clavedlc :" ,  None , "preciojuegoD :" 
          , preciojuego , "preciojuego :", juego[3])
# Out:
# 0.7
# 58
# proveedor : 27 id_transac : 3 id_clave : 2550 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2551 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2552 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2553 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2554 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2555 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2556 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2557 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2558 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2559 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2560 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2561 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2562 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2563 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2564 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2565 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2566 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2567 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2568 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2569 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2570 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2571 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2572 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2573 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2574 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2575 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2576 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2577 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2578 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2579 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2580 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2581 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2582 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2583 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2584 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2585 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2586 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2587 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2588 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2589 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2590 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2591 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2592 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2593 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2594 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2595 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2596 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2597 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2598 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2599 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2600 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2601 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2602 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2603 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2604 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2605 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2606 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
# proveedor : 27 id_transac : 3 id_clave : 2607 id_clavedlc : None preciojuegoD : 1 preciojuego : 2
